# %%
# Install the 'ultralytics' package using pip
# %pip install ultralytics
# %pip install matplotlib
# Out:
# Requirement already satisfied: ultralytics in ./.venv/lib/python3.9/site-packages (8.4.7)
# Requirement already satisfied: numpy>=1.23.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (3.9.4)
# Requirement already satisfied: opencv-python>=4.6.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (4.13.0.90)
# Requirement already satisfied: pillow>=7.1.2 in ./.venv/lib/python3.9/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./.venv/lib/python3.9/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in ./.venv/lib/python3.9/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch<2.10,>=1.8.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil>=5.8.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in ./.venv/lib/python3.9/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in ./.venv/lib/python3.9/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch<2.10,>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.23.0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in ./.venv/lib/python3.9/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.9/site-packages (from sympy>=1.13.3->torch<2.10,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch<2.10,>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the YOLO module from the ultralytics library.
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import os

# %%
# Create an instance of the YOLO model
# Initialize it with the pre-trained weights file 'best.pt' located at the specified path
model = YOLO('best.pt')

# %%
# Define path to video file
source = 'pedestrians.mp4'

# %%
# Run inference on the source
results = model(source, stream=True)

# On récupère la première frame
first_result = next(results)
first_frame = first_result.plot()

h, w, _ = first_frame.shape

output_path = "video_annotated.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # ou 'XVID'
fps = 30  # adapte si nécessaire

video_writer = cv2.VideoWriter(output_path, fourcc, fps, (w, h))

# On écrit la première frame
video_writer.write(first_frame)
# Out:
# video 1/1 (frame 1/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 481.0ms

# %%
# Iterate over each 'result' in the 'results' collection
for result in results:
    # Extract bounding box information from the current 'result'
    boxes = result.boxes
    # Extract mask information from the current 'result'
    masks = result.masks
    # Extract keypoints information from the current 'result'
    keypoints = result.keypoints
    # Extract probability scores from the current 'result'
    probs = result.probs
        # Image annotée (numpy array BGR)
    annotated_frame = result.plot()

    frame = result.plot()
    video_writer.write(frame)
# Now you can use 'boxes', 'masks', 'keypoints', and 'probs' as needed for further processing or analysis.
# These variables hold the relevant information related to the object detection results for the current iteration
video_writer.release()
print(f"Vidéo sauvegardée : {output_path}")
# Out:
# video 1/1 (frame 2/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 5 Humans, 589.7ms
# video 1/1 (frame 3/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 496.8ms
# video 1/1 (frame 4/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 506.5ms
# video 1/1 (frame 5/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 464.8ms
# video 1/1 (frame 6/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 512.6ms
# video 1/1 (frame 7/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 500.0ms
# video 1/1 (frame 8/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 501.1ms
# video 1/1 (frame 9/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 525.1ms
# video 1/1 (frame 10/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 525.9ms
# video 1/1 (frame 11/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 686.8ms
# video 1/1 (frame 12/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 5 Humans, 452.7ms
# video 1/1 (frame 13/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 5 Humans, 510.2ms
# video 1/1 (frame 14/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 6 Humans, 497.7ms
# video 1/1 (frame 15/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 5 Humans, 663.2ms
# video 1/1 (frame 16/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 5 Humans, 540.6ms
# video 1/1 (frame 17/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 466.1ms
# video 1/1 (frame 18/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 483.4ms
# video 1/1 (frame 19/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 595.8ms
# video 1/1 (frame 20/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 835.8ms
# video 1/1 (frame 21/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 741.6ms
# video 1/1 (frame 22/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 532.7ms
# video 1/1 (frame 23/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 506.3ms
# video 1/1 (frame 24/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 535.8ms
# video 1/1 (frame 25/421) /home/nvidia/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/pedestrians.mp4: 384x640 7 Humans, 489.1ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Iterate over each 'result' in the 'results' collection
# ----> 2 for result in results:
#       3     # Extract bounding box information from the current 'result'
#       4     boxes = result.boxes
#       5     # Extract mask information from the current 'result'
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/autobackend.py:701, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     699 # PyTorch
#     700 if self.pt or self.nn_module:
# --> 701     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     703 # TorchScript
#     704 elif self.jit:
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:311, in C2f.forward(self, x)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:311, in <genexpr>(.0)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:481, in Bottleneck.forward(self, x)
#     479 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     480     """Apply bottleneck with optional shortcut connection."""
# --> 481     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/ultralytics/nn/modules/conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)
#      87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Programmation_GPU_HYOT_CHAUVET/Projet/Yolo/YOLOv8-HumanDetection/.venv/lib/python3.9/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
